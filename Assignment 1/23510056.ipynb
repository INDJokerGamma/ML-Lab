# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# a function for keep the count of min value changes in random array 
def min_var_change_count(k, N):

    #this list will store the count of min value changes for each chaneg 
    all_counts = [] 

    for i in range(k):
        #generating an array of N random integers from 1 to 1000000
        arr = np.random.randint(1, 1000000, size=N)

        #this is minimum value 
        mini = 1000000
        count = 0
        j = 0

        while j < len(arr):

            #If current value is smaller than previous min, update it,and increase the count 
            if mini > arr[j]:
                mini = arr[j]
                count += 1

            j = j+ 1

        # add to the list we created 
        all_counts.append(count)

    print(all_counts);

    # Plotting the histogram to show distribution of min change counts
    plt.figure(figsize=(10, 10))
    plt.hist(all_counts, bins=30, edgecolor='black')
    plt.title(f"Histogram of VarChangeCount (N={N})")
    plt.xlabel("VarChangeCount")
    plt.ylabel("Frequency")
    plt.show()


     # Calculate statistics from the collected counts
    mean_val = np.mean(all_counts)
    median_val = np.median(all_counts)
    gmean_val = np.exp(np.mean(np.log(all_counts)))


    # Printing all statistical calculations for this array size
    print(f"N = {N} -> Mean: {mean_val:.2f}, Median: {median_val}, Geometric Mean: {gmean_val:.2f}")

    return mean_val
# the function is ended


Ns = [10, 20, 50, 100, 200, 500, 1000, 2000,
      5000, 10000, 20000, 50000, 100000, 200000, 500000, 1000000]

Mean_Counts = []
# List to store mean var_change_counts for each N

for N in Ns:
    print(f"Processing N={N} ...");
    mean_val = min_var_change_count(k=100, N=N)
    Mean_Counts.append(mean_val)

print(Mean_Counts);
# Plot final result: N vs mean_var_change_count
plt.figure(figsize=(10, 6))
plt.plot(Ns, Mean_Counts, marker='o', linestyle='-', color='blue')
plt.title("Array Size (N) vs Mean var_change_count")
plt.xlabel("Array Size (N)")
plt.ylabel("Mean var_change_count")
plt.show()
# Out:
# Processing N=10 ...
# [2, 3, 2, 2, 2, 4, 2, 2, 2, 3, 4, 4, 2, 5, 5, 6, 2, 3, 4, 4, 1, 2, 4, 3, 4, 4, 3, 1, 3, 4, 2, 2, 4, 3, 1, 3, 4, 3, 4, 2, 3, 2, 2, 2, 2, 2, 1, 1, 4, 4, 5, 2, 2, 2, 2, 6, 2, 4, 3, 1, 3, 4, 2, 2, 2, 4, 2, 2, 2, 5, 4, 2, 2, 2, 3, 1, 4, 3, 5, 6, 1, 5, 3, 5, 3, 4, 5, 2, 3, 4, 3, 1, 4, 2, 1, 2, 1, 1, 2, 2]
# N = 10 -> Mean: 2.86, Median: 3.0, Geometric Mean: 2.56
# Processing N=20 ...
# [4, 1, 3, 6, 6, 2, 5, 3, 1, 3, 5, 4, 8, 2, 3, 5, 6, 7, 2, 2, 6, 3, 3, 1, 5, 4, 4, 3, 3, 4, 4, 3, 3, 4, 3, 3, 3, 4, 4, 5, 4, 3, 3, 2, 4, 3, 5, 3, 1, 2, 3, 3, 5, 4, 2, 3, 3, 1, 5, 1, 8, 4, 5, 3, 3, 1, 6, 4, 3, 3, 3, 4, 5, 6, 4, 4, 3, 4, 4, 4, 4, 2, 7, 2, 2, 4, 7, 4, 7, 5, 2, 3, 4, 6, 4, 4, 6, 5, 3, 4]
# N = 20 -> Mean: 3.76, Median: 4.0, Geometric Mean: 3.40
# Processing N=50 ...
