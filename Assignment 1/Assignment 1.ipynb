# %%
import matplotlib.pyplot as plt

# %%
x= [50,20,90,70,68,32]
y= [14,25,16,14,13,12]
plt.bar(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from statistics import mean, median
from scipy.stats import gmean

def min_var_change_count(k, N):
    var_change_counts = []
    
    for _ in range(k):
        arr = np.random.randint(1, 1000000, size=N)
        temp_min = float('inf')
        var_change_count = 0
        i = 0
        while i < len(arr):
            if temp_min > arr[i]:
                temp_min = arr[i]
                var_change_count += 1
            i += 1
        var_change_counts.append(var_change_count)
    
    # Plot histogram of var_change_counts
    plt.figure(figsize=(8, 4))
    plt.hist(var_change_counts, bins=30, edgecolor='black')
    plt.title(f"Histogram of var_change_count (N={N})")
    plt.xlabel("var_change_count")
    plt.ylabel("Frequency")
    plt.grid(True)
    plt.show()

    # Calculate statistics
    mean_val = mean(var_change_counts)
    median_val = median(var_change_counts)
    geo_mean_val = gmean(var_change_counts)
    mode_val = mode(var_change_counts)
    
    print(f"N = {N} -> Mean: {mean_val:.2f}, Median: {median_val}, Geometric Mean: {geo_mean_val:.2f}, Mode: {mode_val:.2f}")
    
    return mean_val

# Test for multiple values of N
Ns = [10, 20, 50, 100, 200, 500, 1000, 2000,
      5000, 10000, 20000, 50000, 100000, 200000, 500000, 1000000]

mean_var_counts = []

# Run the function for each N and collect mean_var_change_count
for N in Ns:
    print(f"Processing N={N} ...")
    mean_val = min_var_change_count(k=100, N=N)
    mean_var_counts.append(mean_val)

# Plot N vs mean_var_change_count
plt.figure(figsize=(10, 6))
plt.plot(Ns, mean_var_counts, marker='o', linestyle='-', color='blue')
plt.title("Array Size (N) vs Mean var_change_count")
plt.xlabel("Array Size (N)")
plt.ylabel("Mean var_change_count")
plt.grid(True)
plt.xscale("log")  # Log scale for better visualization
plt.tight_layout()
plt.show()
# Out:
# Processing N=10 ...
# N = 10 -> Mean: 2.89, Median: 3.0, Geometric Mean: 2.67, Mode: 3.00
# Processing N=20 ...
# N = 20 -> Mean: 3.45, Median: 3.0, Geometric Mean: 3.13, Mode: 3.00
# Processing N=50 ...
# N = 50 -> Mean: 4.56, Median: 4.5, Geometric Mean: 4.14, Mode: 4.00
# Processing N=100 ...
# N = 100 -> Mean: 5.05, Median: 5.0, Geometric Mean: 4.74, Mode: 5.00
# Processing N=200 ...
# N = 200 -> Mean: 5.99, Median: 6.0, Geometric Mean: 5.60, Mode: 6.00
# Processing N=500 ...
# N = 500 -> Mean: 6.92, Median: 7.0, Geometric Mean: 6.39, Mode: 6.00
# Processing N=1000 ...
# N = 1000 -> Mean: 7.34, Median: 7.0, Geometric Mean: 6.95, Mode: 7.00
# Processing N=2000 ...
# N = 2000 -> Mean: 8.36, Median: 8.0, Geometric Mean: 7.98, Mode: 9.00
# Processing N=5000 ...
# N = 5000 -> Mean: 9.36, Median: 9.0, Geometric Mean: 8.99, Mode: 8.00
# Processing N=10000 ...
# N = 10000 -> Mean: 9.56, Median: 9.0, Geometric Mean: 9.05, Mode: 9.00
# Processing N=20000 ...
# N = 20000 -> Mean: 10.04, Median: 10.0, Geometric Mean: 9.60, Mode: 9.00
# Processing N=50000 ...
# N = 50000 -> Mean: 11.30, Median: 11.0, Geometric Mean: 10.78, Mode: 9.00
# Processing N=100000 ...
# N = 100000 -> Mean: 12.15, Median: 12.0, Geometric Mean: 11.69, Mode: 14.00
# Processing N=200000 ...
# N = 200000 -> Mean: 12.42, Median: 12.0, Geometric Mean: 11.90, Mode: 13.00
# Processing N=500000 ...
